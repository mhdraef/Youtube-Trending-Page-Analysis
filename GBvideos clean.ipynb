# %%
# Code to clean up the data [Replace category id's with respecting category names, changing trending date to date-time format]

# %%
# Load the standard array library
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
# Load the plotting package
import matplotlib.pyplot as plt
# Tell plotting package to show plots in the notebook
# %matplotlib inline
# Make plots a little more fancy.
plt.style.use('fivethirtyeight')

# %%
# Load the standard table manipulation package
import pandas as pd

# %%
df = pd.read_csv('GBvideos.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>video_id</th>
#       <th>trending_date</th>
#       <th>title</th>
#       <th>channel_title</th>
#       <th>category_id</th>
#       <th>publish_time</th>
#       <th>tags</th>
#       <th>views</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>comment_count</th>
#       <th>thumbnail_link</th>
#       <th>comments_disabled</th>
#       <th>ratings_disabled</th>
#       <th>video_error_or_removed</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Jw1Y-zhQURU</td>
#       <td>17.14.11</td>
# ...

# %%
relevant_data = df[['trending_date','title','channel_title','category_id','publish_time','tags','views','likes','dislikes','comment_count']]
relevant_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>trending_date</th>
#       <th>title</th>
#       <th>channel_title</th>
#       <th>category_id</th>
#       <th>publish_time</th>
#       <th>tags</th>
#       <th>views</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>comment_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.14.11</td>
#       <td>John Lewis Christmas Ad 2017 - #MozTheMonster</td>
#       <td>John Lewis</td>
#       <td>26</td>
#       <td>2017-11-10T07:38:29.000Z</td>
#       <td>christmas|"john lewis christmas"|"john lewis"|...</td>
#       <td>7224515</td>
#       <td>55681</td>
# ...

# %%
with open('GB_category_id.json', 'r') as f:
    categories_dict = json.load(f)

items = categories_dict["items"]

data = json_normalize(items)

categories = data[['id','snippet.title']]

cat_id = relevant_data['category_id']

# %%
for i in np.arange(len(categories)):
       cat_id.replace(int(categories.iloc[i,0]),categories.iloc[i,1],inplace=True)

cat_id.replace(29,'Nonprofits & Activism',inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#changing the date format to date time to easily sort through the dates and for easier selection of dates
relevant_data['trending_date']=pd.to_datetime(relevant_data['trending_date'],format='%y.%d.%m')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# We can modify the values in cell 6 to add or remove columns.

# %%
relevant_data.rename(columns={'category_id':'category'},inplace=True)
relevant_data
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>trending_date</th>
#       <th>title</th>
#       <th>channel_title</th>
#       <th>category</th>
#       <th>publish_time</th>
#       <th>tags</th>
#       <th>views</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>comment_count</th>
#     </tr>
#   </thead>
# ...

# %%
relevant_data.to_csv('Clean_GBvideos.csv',index=False)

# %%
#Testing if the file has been written successfully
new = pd.read_csv('Clean_GBvideos.csv')
new
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>trending_date</th>
#       <th>title</th>
#       <th>channel_title</th>
#       <th>category</th>
#       <th>publish_time</th>
#       <th>tags</th>
#       <th>views</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>comment_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-11-14</td>
#       <td>John Lewis Christmas Ad 2017 - #MozTheMonster</td>
#       <td>John Lewis</td>
#       <td>Howto &amp; Style</td>
#       <td>2017-11-10T07:38:29.000Z</td>
#       <td>christmas|"john lewis christmas"|"john lewis"|...</td>
#       <td>7224515</td>
# ...
